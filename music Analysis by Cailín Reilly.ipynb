# %% [markdown]
# Music Data Analysis - Project by Cailín Reilly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Relevant packages imported.

# %%
a = 'Welcome to my Music Data Analysis'
b = 'The End, Thank you for reading!'
def Opening(a):
    print(a)
def Closing(b):
    print(b)

# %%
Opening(a)
# Out:
# Welcome to my Music Data Analysis

# %% [markdown]
# Defined a customer function for Opening/ Closing.

# %%
Spotify_df = pd.read_csv('/Users/cailinreilly/Downloads/*Python/spotify_top50_2021.csv')

# %% [markdown]
# Imported dataset from Kaggle using pandas

# %%
Spotify_df.head()
# Out:
#    id     artist_name                      track_name                track_id  \
# 0   1  Olivia Rodrigo                 drivers license  5wANPM4fQCJwkGd4rN57mH
# 1   2       Lil Nas X  MONTERO (Call Me By Your Name)  1SC5rEoYDGUK4NfG82494W
# 2   3   The Kid LAROI       STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX
# 3   4  Olivia Rodrigo                        good 4 u  4ZtFanR9U6ndgddUvNcjcG
# 4   5        Dua Lipa       Levitating (feat. DaBaby)  5nujrmhLynf4yMoMtj8AQF
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          92         0.561   0.431   10    -8.810     1       0.0578
# 1          90         0.593   0.503    8    -6.725     0       0.2200
# 2          92         0.591   0.764    1    -5.484     1       0.0483
# 3          95         0.563   0.664    9    -5.044     1       0.1540
# 4          89         0.702   0.825    6    -3.787     0       0.0601
#
# ...

# %%
Spotify_df.tail()
# Out:
#     id      artist_name                 track_name                track_id  \
# 45  46         J Balvin              Qué Más Pues?  6D2TCm4nf5nxAcdGJ7w3QP
# 46  47       Joel Corry  Head & Heart (feat. MNEK)  6cx06DFPPHchuUAcTxznu9
# 47  48    Ariana Grande                      34+35  6Im9k8u9iIzKMrmV7BWtlF
# 48  49       Tate McRae         you broke me first  45bE4HXI0AwGZXfZtMp8JR
# 49  50  Sebastian Yatra             Pareja Del Año  2rCbl9naJYhaxjLsfx88uM
#
#     popularity  danceability  energy  key  loudness  mode  speechiness  \
# 45          79         0.903   0.817    8    -3.972     1       0.0950
# 46          86         0.734   0.874    8    -3.158     1       0.0662
# 47          85         0.830   0.585    0    -6.476     1       0.0940
# 48          88         0.667   0.373    4    -9.389     1       0.0500
# 49          86         0.715   0.622    4    -5.102     0       0.0460
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %% [markdown]
# Checking data imported correctly by using.head() and .tail() functions

# %%
Spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   artist_name       50 non-null     object
#  2   track_name        50 non-null     object
#  3   track_id          50 non-null     object
#  4   popularity        50 non-null     int64
#  5   danceability      50 non-null     float64
#  6   energy            50 non-null     float64
#  7   key               50 non-null     int64
#  8   loudness          50 non-null     float64
#  9   mode              50 non-null     int64
#  10  speechiness       50 non-null     float64
#  11  acousticness      50 non-null     float64
#  12  instrumentalness  50 non-null     float64
#  13  liveness          50 non-null     float64
#  14  valence           50 non-null     float64
#  15  tempo             50 non-null     float64
# ...

# %% [markdown]
# Imported data looks clean and numerical fields are corrrectly int, floats.

# %%
Spotify_df.describe()
# Out:
#              id  popularity  danceability    energy        key   loudness  \
# count  50.00000   50.000000     50.000000  50.00000  50.000000  50.000000
# mean   25.50000   86.800000      0.685720   0.64636   5.180000  -5.903920
# std    14.57738    6.266203      0.124987   0.14712   3.868713   2.036948
# min     1.00000   67.000000      0.380000   0.33900   0.000000 -11.639000
# 25%    13.25000   85.250000      0.597750   0.54525   1.000000  -7.186250
# 50%    25.50000   88.000000      0.714500   0.65650   5.500000  -5.485500
# 75%    37.75000   90.000000      0.774500   0.76475   8.000000  -4.258500
# max    50.00000   95.000000      0.903000   0.89300  11.000000  -2.810000
#
#             mode  speechiness  acousticness  instrumentalness   liveness  \
# count  50.000000    50.000000     50.000000         50.000000  50.000000
# mean    0.620000     0.081374      0.253811          0.001606   0.182292
# std     0.490314     0.057164      0.235345          0.006425   0.137799
# ...

# %% [markdown]
# All columns have values and there is a good range of data within the dataset

# %%
Spotify_df.isnull().sum()
# Out:
# id                  0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# Further checks for null values. None found.

# %%
Spotify_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data contains no duplicated values

# %%
Spotify_df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
Spotify_df.set_index('artist_name').head(5)
# Out:
#                 id                      track_name                track_id  \
# artist_name
# Olivia Rodrigo   1                 drivers license  5wANPM4fQCJwkGd4rN57mH
# Lil Nas X        2  MONTERO (Call Me By Your Name)  1SC5rEoYDGUK4NfG82494W
# The Kid LAROI    3       STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX
# Olivia Rodrigo   4                        good 4 u  4ZtFanR9U6ndgddUvNcjcG
# Dua Lipa         5       Levitating (feat. DaBaby)  5nujrmhLynf4yMoMtj8AQF
#
#                 popularity  danceability  energy  key  loudness  mode  \
# artist_name
# Olivia Rodrigo          92         0.561   0.431   10    -8.810     1
# Lil Nas X               90         0.593   0.503    8    -6.725     0
# The Kid LAROI           92         0.591   0.764    1    -5.484     1
# Olivia Rodrigo          95         0.563   0.664    9    -5.044     1
# Dua Lipa                89         0.702   0.825    6    -3.787     0
#
# ...

# %% [markdown]
# Setting index at 'artist name' column.

# %%
Spotify_clean = Spotify_df.drop(['track_id', 'loudness', 'speechiness', 'instrumentalness', 'liveness', 'valence'], axis = 1)

# %%
Spotify_clean
# Out:
#     id        artist_name                                         track_name  \
# 0    1     Olivia Rodrigo                                    drivers license
# 1    2          Lil Nas X                     MONTERO (Call Me By Your Name)
# 2    3      The Kid LAROI                          STAY (with Justin Bieber)
# 3    4     Olivia Rodrigo                                           good 4 u
# 4    5           Dua Lipa                          Levitating (feat. DaBaby)
# 5    6      Justin Bieber             Peaches (feat. Daniel Caesar & Giveon)
# 6    7           Doja Cat                           Kiss Me More (feat. SZA)
# 7    8         The Weeknd                                    Blinding Lights
# 8    9      Glass Animals                                         Heat Waves
# 9   10           Måneskin                                            Beggin'
# 10  11        Masked Wolf                             Astronaut In The Ocean
# ...

# %% [markdown]
# Dropped data not relevant to my analysis

# %%
Spotify_popularity = Spotify_clean.sort_values('popularity', ascending=False)

# %%
Spotify_popularity.head()
# Out:
#     id     artist_name  track_name  popularity  danceability  energy  key  \
# 42  43        Doja Cat       Woman          95         0.824   0.764    5
# 3    4  Olivia Rodrigo    good 4 u          95         0.563   0.664    9
# 13  14      Ed Sheeran  Bad Habits          95         0.807   0.893   11
# 22  23       Bad Bunny    Yonaguni          94         0.644   0.648    1
# 8    9   Glass Animals  Heat Waves          94         0.761   0.525   11
#
#     mode  acousticness    tempo  duration_ms  time_signature
# 42     0        0.0888  107.998       172627               4
# 3      1        0.3350  166.928       178147               4
# 13     0        0.0451  126.011       230747               4
# 22     1        0.2760  179.951       206710               4
# 8      1        0.4400   80.870       238805               4

# %%
Spotify_length = Spotify_clean.sort_values('duration_ms', ascending=True)

# %%
Spotify_length.tail()
# Out:
#     id      artist_name           track_name  popularity  danceability  \
# 0    1   Olivia Rodrigo      drivers license          92         0.561
# 16  17       Bruno Mars  Leave The Door Open          86         0.586
# 38  39  Los Legendarios                 Fiel          82         0.849
# 44  45              SZA            Good Days          86         0.436
# 29  30          Farruko                Pepas          86         0.762
#
#     energy  key  mode  acousticness    tempo  duration_ms  time_signature
# 0    0.431   10     1       0.76800  143.875       242013               4
# 16   0.616    5     1       0.18200  148.088       242096               4
# 38   0.701    6     0       0.40700   98.005       261667               4
# 44   0.655    1     0       0.49900  121.002       279204               4
# 29   0.766    7     1       0.00776  130.001       287120               4

# %%
Spotify_length.head()
# Out:
#     id    artist_name                      track_name  popularity  \
# 10  11    Masked Wolf          Astronaut In The Ocean          77
# 1    2      Lil Nas X  MONTERO (Call Me By Your Name)          90
# 19  20       24kGoldn          Mood (feat. iann dior)          89
# 2    3  The Kid LAROI       STAY (with Justin Bieber)          92
# 25  26     Kali Uchis                       telepatía          87
#
#     danceability  energy  key  mode  acousticness    tempo  duration_ms  \
# 10         0.778   0.695    4     0        0.1750  149.996       132780
# 1          0.593   0.503    8     0        0.2930  178.781       137704
# 19         0.701   0.716    7     0        0.1740   91.007       140533
# 2          0.591   0.764    1     1        0.0383  169.928       141806
# 25         0.653   0.524   11     0        0.1120   83.970       160191
#
#     time_signature
# 10               4
# 1                4
# 19               4
# 2                4
# 25               4

# %% [markdown]
# Looking closer at Top 50 songs by popularity and length. None of the top 5 most popoular songs are on the top 5 longest or shortest songs.

# %%
plt.plot(Spotify_clean['popularity'], Spotify_clean['duration_ms'])
plt.xlabel('Popularity of Song')
plt.ylabel('Length of song in MS')
plt.title('Spotify Top 50 songs of 2021 - Length/ Popularity')
# Out:
# Text(0.5, 1.0, 'Spotify Top 50 songs of 2021 - Length/ Popularity')

# %% [markdown]
# Using plot visualisation through Matplotlib further demonstrates there is no correlation between duration in MS and popularity of Top 50 songs.

# %%
tiktok_df = pd.read_csv('/Users/cailinreilly/Downloads/*Python/TikTok_songs_2021.csv')

# %%
tiktok_df.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0               STAY (with Justin Bieber)  The Kid LAROI          83
# 1  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 2              edamame (feat. Rich Brian)          bbno$          72
# 3                     Here's Your Perfect   Jamie Miller          65
# 4                                It's You        Sezairi          57
#
#                         album  track_pop  danceability  energy  loudness  \
# 0   STAY (with Justin Bieber)         89         0.591   0.764    -5.484
# 1                     Justice         86         0.677   0.696    -6.181
# 2  edamame (feat. Rich Brian)         77         0.815   0.848    -4.704
# 3         Here's Your Perfect         77         0.558   0.454    -5.335
# 4                    It's You         73         0.630   0.456    -8.285
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# Imported another dataset from Kaggle: Tiktok songs from 2021 and checked the top 5

# %%
tiktok_clean = tiktok_df.drop(['artist_pop', 'loudness', 'speechiness', 'instrumentalness', 'liveness', 'valence'], axis = 1)

# %%
tiktok_clean2 = tiktok_clean.rename(columns={'track_pop':'popularity'})

# %%
tiktok_clean2
# Out:
#                                  track_name    artist_name  \
# 0                 STAY (with Justin Bieber)  The Kid LAROI
# 1    Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber
# 2                edamame (feat. Rich Brian)          bbno$
# 3                       Here's Your Perfect   Jamie Miller
# 4                                  It's You        Sezairi
# ..                                      ...            ...
# 185                                   Panda      Desiigner
# 186                             TO THE MOON       Jnr Choi
# 187                             Upside Down           JVKE
# 188                                  lowkey           NIKI
# 189               Desce Pro Play (PA PA PA)           ZAAC
#
#                           album  popularity  danceability  energy  mode  key  \
# 0     STAY (with Justin Bieber)          89         0.591   0.764     1    1
# 1                       Justice          86         0.677   0.696     1    0
# ...

# %% [markdown]
# Dropped un-needed columns once more on new dataset. Also renamed 'track_pop' to match with 'popularity on prev dataset(Stpotify)

# %%
tiktok_top10 = tiktok_clean2.head(10)

# %%
sns.barplot(x = "artist_name", y = "popularity", data = tiktok_top10)
plt.xticks(rotation =45);

# %%
Spotify_top10 = Spotify_clean.head(10)

# %%
sns.barplot(x = "artist_name", y = "popularity", data = Spotify_top10)
plt.xticks(rotation =45);

# %% [markdown]
# Looking at artist name / popularity across both datasets seperately. The Kid LAROI, Justin Beiber and Olivia Rodrigo all feature within the top 10 most popular on Spotify in 2021 and TikTok.

# %%
spotify_tiktok = pd.concat([Spotify_clean, tiktok_clean2], axis=0)

# %%
spotify_tiktok.head(10)
# Out:
#      id     artist_name                              track_name  popularity  \
# 0   1.0  Olivia Rodrigo                         drivers license          92
# 1   2.0       Lil Nas X          MONTERO (Call Me By Your Name)          90
# 2   3.0   The Kid LAROI               STAY (with Justin Bieber)          92
# 3   4.0  Olivia Rodrigo                                good 4 u          95
# 4   5.0        Dua Lipa               Levitating (feat. DaBaby)          89
# 5   6.0   Justin Bieber  Peaches (feat. Daniel Caesar & Giveon)          90
# 6   7.0        Doja Cat                Kiss Me More (feat. SZA)          88
# 7   8.0      The Weeknd                         Blinding Lights          93
# 8   9.0   Glass Animals                              Heat Waves          94
# 9  10.0        Måneskin                                 Beggin'          93
#
#    danceability  energy  key  mode  acousticness    tempo  duration_ms  \
# ...

# %% [markdown]
# Merged the 2 datasets (Tiktok into Spotify) and checked the first 10 records.

# %%
plt.subplots(figsize=(8,10))
sns.scatterplot(data=spotify_tiktok, x="danceability", y="popularity",color='pink')
plt.xlabel('Danceability')
plt.ylabel('Popularity of Song')
plt.title('Popularity/ Danceability Comparison')
# Out:
# Text(0.5, 1.0, 'Popularity/ Danceability Comparison')

# %% [markdown]
# Looking at the comparison between danceability and overall popularity, you can see visually there are more dots scattered at the top of the scatter plot. This shows that the more popular songs are usually higher rated on the daceability scale. We can see that this isn't the case for all songs but certainly, the majority.
#
# The most 'danceable' song is somewhere between 70-80 on the popularity scale.
#
# The most popular song is between 0.8 - 0.9 on the 'danceable' scale.
#
# *Chose to change dot color to pink.

# %%
spotify_tiktok[20:30][['artist_name', 'track_name', 'popularity','danceability', 'duration_ms']]
# Out:
#        artist_name                                         track_name  \
# 20          Tiësto                                       The Business
# 21             BTS                                           Dynamite
# 22       Bad Bunny                                           Yonaguni
# 23    Harry Styles                                   Watermelon Sugar
# 24           Riton  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...
# 25      Kali Uchis                                          telepatía
# 26   The Kid LAROI                                        WITHOUT YOU
# 27          Giveon                             Heartbreak Anniversary
# 28  Olivia Rodrigo                                            traitor
# 29         Farruko                                              Pepas
#
#     popularity  danceability  duration_ms
# 20          88         0.798       164000
# 21          67         0.746       199054
# 22          94         0.644       206710
# ...

# %%
spotify_tiktok.iloc[25,4]
# Out:
# 0.653

# %%
spotify_tiktok.iloc[[0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50], [2, 3, 4]]
# Out:
#                                 track_name  popularity  danceability
# 0                          drivers license          92         0.561
# 5   Peaches (feat. Daniel Caesar & Giveon)          90         0.677
# 10                  Astronaut In The Ocean          77         0.778
# 15                                  Butter          71         0.759
# 20                            The Business          88         0.798
# 25                               telepatía          87         0.653
# 30                               positions          88         0.737
# 35                      LA NOCHE DE ANOCHE          87         0.856
# 40                         Don't Start Now          84         0.793
# 45                           Qué Más Pues?          79         0.903
# 0                STAY (with Justin Bieber)          89         0.591

# %% [markdown]
# Using iloc to slice into the data to get a closer look;
#
# Looked closer at rows 20-30
#
# The 25th rows 'danceability'
#
# Every 5th song's name, popularity and danceability

# %%
spotify_tiktok[(spotify_tiktok['popularity'] >= 80) & (spotify_tiktok['popularity'] < 90)].head(5)
# Out:
#       id artist_name                 track_name  popularity  danceability  \
# 4    5.0    Dua Lipa  Levitating (feat. DaBaby)          89         0.702
# 6    7.0    Doja Cat   Kiss Me More (feat. SZA)          88         0.764
# 11  12.0   Bad Bunny                     DÁKITI          87         0.731
# 16  17.0  Bruno Mars        Leave The Door Open          86         0.586
# 19  20.0    24kGoldn     Mood (feat. iann dior)          89         0.701
#
#     energy  key  mode  acousticness    tempo  duration_ms  time_signature  \
# 4    0.825    6     0       0.00883  102.977       203064               4
# 6    0.705    8     1       0.25900  110.970       208667               4
# 11   0.573    4     0       0.40100  109.928       205090               4
# 16   0.616    5     1       0.18200  148.088       242096               4
# 19   0.716    7     0       0.17400   91.007       140533               4
#
#    album
# 4    NaN
# 6    NaN
# 11   NaN
# 16   NaN
# 19   NaN

# %%
spotify_tiktok[(spotify_tiktok['popularity'] >= 50) & (spotify_tiktok['popularity'] < 60)].head(5)
# Out:
#     id    artist_name        track_name  popularity  danceability  energy  \
# 17 NaN  New Hope Club  Know Me Too Well          59         0.750   0.698
# 21 NaN           Iyaz            So Big          52         0.697   0.688
# 28 NaN         Konfuz            Ратата          59         0.921   0.524
# 48 NaN          Lenka          The Show          57         0.753   0.590
# 49 NaN      Terror Jr         3 Strikes          56         0.599   0.432
#
#     key  mode  acousticness    tempo  duration_ms  time_signature  \
# 17    1     0         0.427  122.954       200013               4
# 21    6     1         0.290  121.962       199920               4
# 28    8     0         0.172  129.995       137077               4
# 48    0     1         0.259  123.028       235693               4
# 49    5     1         0.620  106.824       175777               5
#
#                        album
# 17          Know Me Too Well
# 21                    Replay
# 28                    Ратата
# ...

# %%
spotify_tiktok[spotify_tiktok['danceability'] < 0.4].head(2)
# Out:
#       id     artist_name track_name  popularity  danceability  energy  key  \
# 28  29.0  Olivia Rodrigo    traitor          92         0.380   0.339    3
# 7    NaN    Madison Beer   Reckless          78         0.386   0.426    3
#
#     mode  acousticness    tempo  duration_ms  time_signature     album
# 28     1         0.691  100.607       229227               4       NaN
# 7      1         0.807  180.104       203385               3  Reckless

# %% [markdown]
# Using filtering and boolean functions to look at;
#
# Popularity rating between 80-90 / 50-60
#
# Danceability less than a 0.4

# %%
spotify_tiktok.groupby(['artist_name']).mean().sort_values('popularity', ascending=False)
# Out:
#                      id  popularity  danceability  energy   key  mode  \
# artist_name
# The Neighbourhood  38.0        92.0         0.612   0.807  10.0   1.0
# Elley Duhé          NaN        91.0         0.410   0.611   4.0   0.0
# Ruth B.             NaN        90.0         0.609   0.692   1.0   1.0
# Harry Styles       24.0        90.0         0.548   0.816   0.0   1.0
# Glass Animals       9.0        89.5         0.761   0.525  11.0   1.0
# ...                 ...         ...           ...     ...   ...   ...
# Tai Verdes          NaN         0.0         0.844   0.429   2.0   1.0
# Eduardo Luzquiños   NaN         0.0         0.808   0.782   7.0   0.0
# Eric D              NaN         0.0         0.757   0.836   1.0   0.0
# Lizz Robinett       NaN         0.0         0.896   0.555   4.0   1.0
# Daya                NaN         0.0         0.657   0.739   2.0   1.0
#
#                    acousticness    tempo  duration_ms  time_signature
# artist_name
# ...

# %%
spotify_tiktok.groupby(['album']).mean().sort_values('popularity', ascending=False)
# Out:
#                                              id  popularity  danceability  \
# album
# MIDDLE OF THE NIGHT                         NaN        91.0         0.410
# Safe Haven                                  NaN        90.0         0.609
# STAY (with Justin Bieber)                   NaN        89.0         0.591
# MONTERO                                     NaN        88.0         0.737
# After Hours                                 NaN        88.0         0.680
# ...                                          ..         ...           ...
# Renai Circulation (English Cover) [TV Size] NaN         0.0         0.896
# Savage Days                                 NaN         0.0         0.757
# YRN (Remix)                                 NaN         0.0         0.808
# Sit Still, Look Pretty                      NaN         0.0         0.657
# Stuck in the Middle                         NaN         0.0         0.844
#
# ...

# %% [markdown]
# Grouping by both album and artist name to look at the mean of the data, top 10 in both cases, alphabetically. Sorted by 'popularity' in both cases.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-streamed_songs_on_Spotify'
Wiki_table = pd.read_html(url)
Streams_Alltime = Wiki_table[0]
Streams_Alltime
# Out:
#                         Rank                    Song[A]  \
# 0                          1             "Shape Of You"
# 1                          2          "Blinding Lights"
# 2                          3             "Dance Monkey"
# 3                          4                 "Rockstar"
# 4                          5        "Someone You Loved"
# ..                       ...                        ...
# 96                        97               "Youngblood"
# 97                        98                    "Sugar"
# 98                        99  "Can't Stop the Feeling!"
# 99                       100                 "Heathens"
# 100  As of 25 September 2022    As of 25 September 2022
#
#            Streams(Billions)                        Artist(s)  \
# 0                      3.243                       Ed Sheeran
# 1                      3.162                       The Weeknd
# 2                      2.657                      Tones And I
# ...

# %% [markdown]
# Webscraping a table from Wikipedia to look at the all time top streams on Spotify.
# The data collected shows Rank, Song, Streams in billions, Artist and Date published.

# %%
Streams_Alltime = Streams_Alltime.drop(['Ref.',], axis=1)

# %% [markdown]
# Dropping 'Ref.' column as it contains links, which have not flowed over via the webscraping.

# %%
Streams_array = np.array([[3.241, 3.162, 2.657, 2.504, 2.478], 
                          [1.415, 1.424, 1.426, 1.429, 1.431]])

Streams_array
# Out:
# array([[3.241, 3.162, 2.657, 2.504, 2.478],
#        [1.415, 1.424, 1.426, 1.429, 1.431]])

# %%
Rounded_streams = np.round_(Streams_array, decimals = 1)

# %%
Rounded_streams
# Out:
# array([[3.2, 3.2, 2.7, 2.5, 2.5],
#        [1.4, 1.4, 1.4, 1.4, 1.4]])

# %%
Rounded_streams.mean()
# Out:
# 2.11

# %% [markdown]
# Created a numpy array to look at the top 5 and bottom 5 in terms of 'Rank' by the Steams in Billions.
#
# I rounded the streams in billions to 1 decimal place and also got the mean of the 10 values using numpy.

# %%
song = ["Shape Of You", "Blinding Lights", "Dance Monkey", "Rockstar", "Someone You Loved"]
streams = streams = [3.241, 3.162, 2.657, 2.504, 2.478]
sns.barplot(x= song, y= streams)
plt.xticks(rotation =90);

# %% [markdown]
# Created lists from the top 5 Songs and Streams in billions and visualised results in a Seaborn Barplot.

# %%
Streams_Alltime.tail()
# Out:
#                         Rank                    Song[A]  \
# 96                        97               "Youngblood"
# 97                        98                    "Sugar"
# 98                        99  "Can't Stop the Feeling!"
# 99                       100                 "Heathens"
# 100  As of 25 September 2022    As of 25 September 2022
#
#            Streams(Billions)                Artist(s)           Date published
# 96                     1.430      5 Seconds Of Summer            12 April 2018
# 97                     1.427                 Maroon 5           29 August 2014
# 98                     1.425        Justin Timberlake               6 May 2016
# 99                     1.417        Twenty One Pilots             16 June 2016
# 100  As of 25 September 2022  As of 25 September 2022  As of 25 September 2022

# %%
Streams_Alltime.drop([100,], axis=0)
# Out:
#    Rank                    Song[A] Streams(Billions)  \
# 0     1             "Shape Of You"             3.243
# 1     2          "Blinding Lights"             3.162
# 2     3             "Dance Monkey"             2.657
# 3     4                 "Rockstar"             2.504
# 4     5        "Someone You Loved"             2.478
# ..  ...                        ...               ...
# 95   96         "'Till I Collapse"             1.433
# 96   97               "Youngblood"             1.430
# 97   98                    "Sugar"             1.427
# 98   99  "Can't Stop the Feeling!"             1.425
# 99  100                 "Heathens"             1.417
#
#                           Artist(s)     Date published
# 0                        Ed Sheeran     6 January 2017
# 1                        The Weeknd   29 November 2019
# 2                       Tones And I        10 May 2019
# 3   Post Malone featuring 21 Savage  15 September 2017
# ...

# %%
Low_Rank_Streams = {"Heathens":"Twenty One Pilots", "Can't Stop the Feeling!":"Justin Timberlake", "Sugar":"Maroon 5", "Youngblood":"5 Seconds Of Summer", "Till I Collapse":"Eminem featuring Nate Dogg"}
for x in Low_Rank_Streams:
    print(x)
# Out:
# Heathens
# Can't Stop the Feeling!
# Sugar
# Youngblood
# Till I Collapse

# %% [markdown]
# Looking at the tail of the data collected, Row 100 was not actual data. Dropped row 100.
# Created a dictionary with the 5 lowest ranked songs on the dataset.
# Used a for loop to display the 'Song' in each case.

# %%
for index, row in Streams_Alltime.head().iterrows():
    print(index)
    print(row)
# Out:
# 0
# Rank                              1
# Song[A]              "Shape Of You"
# Streams(Billions)             3.243
# Artist(s)                Ed Sheeran
# Date published       6 January 2017
# Name: 0, dtype: object
# 1
# Rank                                 2
# Song[A]              "Blinding Lights"
# Streams(Billions)                3.162
# Artist(s)                   The Weeknd
# Date published        29 November 2019
# Name: 1, dtype: object
# 2
# Rank                              3
# Song[A]              "Dance Monkey"
# Streams(Billions)             2.657
# Artist(s)               Tones And I
# Date published          10 May 2019
# Name: 2, dtype: object
# 3
# Rank                                               4
# Song[A]                                   "Rockstar"
# Streams(Billions)                              2.504
# Artist(s)            Post Malone featuring 21 Savage
# Date published                     15 September 2017
# Name: 3, dtype: object
# 4
# ...

# %%
for index, row in Streams_Alltime.head().iterrows():
    print(f"{row[1]} by {row[3]} was streamed a total of {row[2]} billion times")
# Out:
# "Shape Of You" by Ed Sheeran was streamed a total of 3.243 billion times
# "Blinding Lights" by The Weeknd was streamed a total of 3.162 billion times
# "Dance Monkey" by Tones And I was streamed a total of 2.657 billion times
# "Rockstar" by Post Malone featuring 21 Savage was streamed a total of 2.504 billion times
# "Someone You Loved" by Lewis Capaldi was streamed a total of 2.478 billion times

# %% [markdown]
# Continued using for looping to look at the data in the head() of the dataset.
# Used for looping to iterate over the dataset head to display the first 5 results in sentences.

# %%
Closing(b)
# Out:
# The End, Thank you for reading!
